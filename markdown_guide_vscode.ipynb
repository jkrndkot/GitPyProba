# %% [markdown]
# # 📘 Markdown в VSCode Jupyter: шпаргалка
#
# ## 🔧 Основы
# VSCode с установленным расширением **Jupyter** поддерживает Markdown-ячейки по стандарту Jupyter Notebook с HTML-дополнениями.
#
# 📌 Чтобы вставить Markdown:
# - выбери тип ячейки **Markdown**
# - нажми `Shift+Enter` для отображения
#
# ---
#
# ## 🧱 Заголовки
#
# ```markdown
# # Заголовок 1
# ## Заголовок 2
# ### Заголовок 3
# ```
#
# ---
#
# ## 💬 Выделение текста
#
# ```markdown
# **жирный текст**
# *курсив*
# ~~зачёркнутый~~
# `моноширинный`
# ```
#
# ---
#
# ## 📍 Списки
#
# ```markdown
# - Первый элемент
# - Второй
#   - Подпункт
#
# 1. Нумерованный
# 2. Тоже нумерованный
# ```
#
# ---
#
# ## 🔗 Ссылки и изображения
#
# ```markdown
# [ссылка](https://example.com)
# ![альтернативный текст](image.png)
# ```
#
# ---
#
# ## 💡 Новая строка
#
# ```markdown
# Первая строка
# Вторая строка
# ```
#
# > 👆 Обрати внимание: **два пробела в конце строки** — обязательны для переноса!
#
# ---
#
# ## 🎨 Цветной текст (HTML-трюк)
#
# ```markdown
# <span style="color:red;">Красный текст</span>
# <span style="color:limegreen;">Зелёный текст</span>
# ```
#
# > ⚠️ **Работает только в Markdown-ячейке и при включённом WebView Jupyter Renderer.** Не работает в обычных Markdown-файлах VSCode!
#
# ---
#
# ## 🧪 Пример с путём:
#
# ```markdown
# C:\Users\<span style="color:red;">Иван</span>\AppData\Local\Programs\Python\
# ```
#
# ---
#
# ## 🧱 Горизонтальная линия
#
# ```markdown
# ---
# ```
#
# ---
#
# ## ⚠️ Ограничения
#
# | Фича                        | VSCode (Jupyter) | Обычный Markdown |
# |----------------------------|------------------|------------------|
# | `<span style="...">`       | ✅ Да             | ❌ Нет           |
# | Поддержка `<div>`, `<style>` | ❌ Нет            | ❌ Нет           |
# | Эмодзи                     | ✅ Да             | ✅ Да             |
#
# ---
#
# ## 🛠️ Рекомендации
#
# - Используй HTML-цвет только для кратких фраз.
# - Проверяй отображение сразу после `Shift+Enter`.
# - Если не работает — убедись, что ячейка **Markdown**, а не **Code**.
# - Не вставляй двойные слеши (`\\`) в пути без необходимости.
